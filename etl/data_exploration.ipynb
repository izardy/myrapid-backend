# %%
'''
#read data from google drive
import pandas as pd

url_route='https://drive.google.com/file/d/1Zpo2zNZ3V1W1X4Z-icmugbCMZwHIcvCQ/view?usp=sharing' #route data
file_id_route=url_route.split('/')[-2]
dwn_url_route='https://drive.google.com/uc?id=' + file_id_route

url_rtd='https://drive.google.com/file/d/1rsJl1dTXFxP9NdzYWQDg-Mi5uaPq7Sdt/view?usp=sharing' # rtd data
file_id_rtd=url_rtd.split('/')[-2]
dwn_url_rtd='https://drive.google.com/uc?id=' + file_id_rtd

url_routebusstop='https://drive.google.com/file/d/1oUXNyNECeB5mewBGC-gOnBObddnUxJtH/view?usp=sharing' # route bus stop data
file_id_routebusstop=url_routebusstop.split('/')[-2]
dwn_url_routebusstop='https://drive.google.com/uc?id=' + file_id_routebusstop

url_engbusrepair='https://drive.google.com/file/d/1j1TaaCFTjo6QPAjTLA0oO0EvP5PZKuT3/view?usp=sharing' # eng bus repair data
file_id_engbusrepair=url_engbusrepair.split('/')[-2]
dwn_url_engbusrepair='https://drive.google.com/uc?id=' + file_id_engbusrepair

url_depot='https://drive.google.com/file/d/12t8aUsXqHgv7d4N448naa9ELAUz543pu/view?usp=sharing' # depot data
file_id_depot=url_depot.split('/')[-2]
dwn_url_depot='https://drive.google.com/uc?id=' + file_id_depot

url_captschedule='https://drive.google.com/file/d/1bc1QUGgn-pNGh2EEgqNPktekh1sVnVn0/view?usp=sharing' # captain schedule data ##
file_id_captschedule=url_captschedule.split('/')[-2]
dwn_url_captschedule='https://drive.google.com/uc?id=' + file_id_captschedule


url_busstoplist='https://drive.google.com/file/d/1Ht9MtdExwMTSl_nlvT6xePbrVcrelYVa/view?usp=sharing' # bus stop list data
file_id_busstoplist=url_busstoplist.split('/')[-2]
dwn_url_busstoplist='https://drive.google.com/uc?id=' + file_id_busstoplist

url_accident='https://drive.google.com/file/d/1Z9Dw_Qcb3JWnowbCmsZn9EDDBTJwmrJN/view?usp=sharing' # accident data
file_id_accident=url_accident.split('/')[-2]
dwn_url_accident='https://drive.google.com/uc?id=' + file_id_accident

url_tripdeparture='https://drive.google.com/file/d/1ax4m65Ev0awt1nkE_aLYurhO5Ydp-cHt/view?usp=sharing' # trip departure data ##
file_id_tripdeparture=url_tripdeparture.split('/')[-2]
dwn_url_tripdeparture='https://drive.google.com/uc?id=' + file_id_tripdeparture

'''
# Out:
# "\n#read data from google drive\nimport pandas as pd\n\nurl_route='https://drive.google.com/file/d/1Zpo2zNZ3V1W1X4Z-icmugbCMZwHIcvCQ/view?usp=sharing' #route data\nfile_id_route=url_route.split('/')[-2]\ndwn_url_route='https://drive.google.com/uc?id=' + file_id_route\n\nurl_rtd='https://drive.google.com/file/d/1rsJl1dTXFxP9NdzYWQDg-Mi5uaPq7Sdt/view?usp=sharing' # rtd data\nfile_id_rtd=url_rtd.split('/')[-2]\ndwn_url_rtd='https://drive.google.com/uc?id=' + file_id_rtd\n\nurl_routebusstop='https://drive.google.com/file/d/1oUXNyNECeB5mewBGC-gOnBObddnUxJtH/view?usp=sharing' # route bus stop data\nfile_id_routebusstop=url_routebusstop.split('/')[-2]\ndwn_url_routebusstop='https://drive.google.com/uc?id=' + file_id_routebusstop\n\nurl_engbusrepair='https://drive.google.com/file/d/1j1TaaCFTjo6QPAjTLA0oO0EvP5PZKuT3/view?usp=sharing' # eng bus repair data\nfile_id_engbusrepair=url_engbusrepair.split('/')[-2]\ndwn_url_engbusrepair='https://drive.google.com/uc?id=' + file_id_engbusrepair\n\nurl
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Splitting Data (100MB >) Into Smaller Chunks

# %%
#identifying timestamp from the obtained data of daily trip for Rapid's buses 
pd.read_csv('../data/trip_departure.csv')[['ope_date']].drop_duplicates() # output below indicate data availibility is from 1st Jan 2022 to 30th Jun 2023
# Out:
#            ope_date
# 0        2022-01-01
# 13550    2022-01-02
# 26984    2022-01-03
# 41912    2022-01-04
# 56808    2022-01-05
# ...             ...
# 8015940  2023-06-26
# 8031002  2023-06-27
# 8046136  2023-06-28
# 8060638  2023-06-29
# 8074884  2023-06-30
#
# [546 rows x 1 columns]

# %%
trip_departure=pd.read_csv('../data/trip_departure.csv')
trip_departure['ope_date']=pd.to_datetime(trip_departure['ope_date'])
trip_departure
# Out:
#             td_id   ope_date  depot_id line_id captain_id   bus_no code_duty  \
# 0        34416614 2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 1        34416615 2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 2        34416616 2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 3        34416617 2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 4        34416618 2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# ...           ...        ...       ...     ...        ...      ...       ...
# 8088971  48628449 2023-06-30         7   U7700   MMTTCVUR  VGF4516       NaN
# 8088972  48628450 2023-06-30         7   U7700   VLCPCYFT  VGF4514       NaN
# 8088973  48628451 2023-06-30         7   U7700   VLCPCYFT  VGF4514       NaN
# 8088974  48628462 2023-06-30         7   T7830   TRGEHBIJ  CDH2346       NaN
# 8088975  48628463 2023-06-30         7   T7830   TRGEHBIJ  CDH2346       NaN
#
# ...

# %%
#split trip departure data

months=list(range(1,13,1))
years=list(range(2022,2024,1))

for year in years:
    for month in months:
        filename='../data/trip_departure/trip_departure_'+str(month)+'_'+str(year)+'.csv'
        trip_departure[(trip_departure['ope_date'].dt.month==month)&(trip_departure['ope_date'].dt.year==year)].to_csv(filename,index=False)

# %%
pd.read_csv('../data/captain_schedule.csv')[['cs_date']].drop_duplicates()
# Out:
#            cs_date
# 0       2022-01-01
# 97      2022-01-02
# 200     2022-01-03
# 317     2022-01-04
# 431     2022-01-05
# ...            ...
# 743309  2023-06-26
# 743316  2023-06-27
# 743335  2023-06-28
# 743704  2023-06-29
# 743714  2023-06-30
#
# [546 rows x 1 columns]

# %%
#identifying timestamp from the obtained data of captain schedule for Rapid's buses 
captain_schedule=pd.read_csv('../data/captain_schedule/captain_schedule.csv')# output below indicate data availibility is from 1st Jan 2022 to 30th Jun 2023 
captain_schedule['cs_date']=pd.to_datetime(captain_schedule['cs_date'])
captain_schedule
# Out:
#           cs_id    cs_date cs_codeduty     cs_startduty     cs_reporthub  \
# 0       3507779 2022-01-01         AM1  0 days 05:15:00  0 days 05:55:00
# 1       3507780 2022-01-01         AM2  0 days 05:15:00  0 days 05:55:00
# 2       3507781 2022-01-01         AM3  0 days 05:25:00  0 days 06:05:00
# 3       3507782 2022-01-01         AM4  0 days 05:25:00  0 days 06:05:00
# 4       3507783 2022-01-01         AM5  0 days 05:30:00  0 days 06:15:00
# ...         ...        ...         ...              ...              ...
# 761331  4395486 2023-06-30         DR1  0 days 05:50:00  0 days 06:20:00
# 761332  4395487 2023-06-30         AM1  0 days 05:15:00  0 days 06:20:00
# 761333  4395488 2023-06-30         PM1  0 days 14:40:00  0 days 15:35:00
# 761334  4395489 2023-06-30         AM2  0 days 06:15:00  0 days 07:20:00
# 761335  4395490 2023-06-30         PM2  0 days 12:25:00  0 days 13:20:00
#
#            cs_firsttrip       cs_endduty  cs_totaltrip            cs_startat  \
# ...

# %%
#split captain schedule data

months=list(range(1,13,1))
years=list(range(2022,2024,1))

for year in years:
    for month in months:
        filename='../data/captain_schedule_'+str(month)+'_'+str(year)+'.csv'
        captain_schedule[(captain_schedule['cs_date'].dt.month==month)&(captain_schedule['cs_date'].dt.year==year)].to_csv(filename,index=False)

# %% [markdown]
# ### Trip Departure Data Exploration (Sample for Jan 2022)

# %%
trip_departure_1_2022=pd.read_csv('../data/trip_departure/trip_departure_1_2022.csv')
trip_departure_1_2022
# Out:
#            td_id    ope_date  depot_id line_id captain_id   bus_no code_duty  \
# 0       34416614  2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 1       34416615  2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 2       34416616  2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 3       34416617  2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# 4       34416618  2022-01-01         4   U3000   EOHJDILF  VGL1376       AM1
# ...          ...         ...       ...     ...        ...      ...       ...
# 448019  35080541  2022-01-31         7   T7560   PXXIVEWD  WQA5704       SP1
# 448020  35080572  2022-01-31         7   T7780   EDYXAENC  WVD3298       PM1
# 448021  35080573  2022-01-31         7   T7780   EDYXAENC  WVD3298       PM1
# 448022  35080574  2022-01-31         7   T7780   EDYXAENC  WVD3298       PM1
# 448023  35080575  2022-01-31         7   T7780   EDYXAENC  WVD3298       PM1
#
# ...

# %%
#data model using sample data

trip_departure_1_1_2022_VGL1376=trip_departure_1_2022[(trip_departure_1_2022['bus_no']=='WVN5576')&(trip_departure_1_2022['ope_date']=='2022-01-31')]
trip_departure_1_1_2022_VGL1376['dt_gps']=pd.to_datetime(trip_departure_1_1_2022_VGL1376['dt_gps'])
trip_departure_1_1_2022_VGL1376=trip_departure_1_1_2022_VGL1376.sort_values('dt_gps')
trip_departure_1_1_2022_VGL1376['diff_minutes']=pd.to_datetime(trip_departure_1_1_2022_VGL1376['dt_gps']).diff()/np.timedelta64(1, 'm')

trip_departure_1_1_2022_VGL1376['diff_label']=np.where((trip_departure_1_1_2022_VGL1376['dir']=='arrive')&(trip_departure_1_1_2022_VGL1376['direction']=='DIR2_arrive'),'from point a',np.nan)
trip_departure_1_1_2022_VGL1376['diff_label']=np.where((trip_departure_1_1_2022_VGL1376['dir']=='arrive')&(trip_departure_1_1_2022_VGL1376['direction']=='DIR1_arrive'),'to point a',trip_departure_1_1_2022_VGL1376['diff_label'])
trip_departure_1_1_2022_VGL1376['diff_label']=np.where((trip_departure_1_1_2022_VGL1376['dir']=='depart')&(trip_departure_1_1_2022_VGL1376['direction']=='DIR1_depart'),'idle mode',trip_departure_1_1_2022_VGL1376['diff_label'])
trip_departure_1_1_2022_VGL1376['diff_label']=np.where((trip_departure_1_1_2022_VGL1376['dir']=='depart')&(trip_departure_1_1_2022_VGL1376['direction']=='DIR2_depart'),'idle mode',trip_departure_1_1_2022_VGL1376['diff_label'])
'''
trip_departure_1_1_2022_VGL1376_1=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no'])[['td_id']].count().reset_index().rename(columns={'td_id':'ttl_td_id'}) # total trips on date
trip_departure_1_1_2022_VGL1376_2=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no'])[['captain_id']].nunique().reset_index().rename(columns={'captain_id':'ttl_captain_id'}) # total captains on duty on date
trip_departure_1_1_2022_VGL1376_3=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no'])[['point_a']].nunique().reset_index().rename(columns={'point_a':'ttl_point_a'}) # total point a of trip on date
trip_departure_1_1_2022_VGL1376_4=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no'])[['point_b']].nunique().reset_index().rename(columns={'point_b':'ttl_point_b'}) # total point b of trip on date

trip_departure_1_1_2022_VGL1376_5=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'max'}).reset_index().rename(columns={'diff_minutes':'max_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_6=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'max'}).reset_index().rename(columns={'diff_minutes':'max_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_7=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'max'}).reset_index().rename(columns={'diff_minutes':'max_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_1_2022_VGL1376_8=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'min'}).reset_index().rename(columns={'diff_minutes':'min_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_9=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'min'}).reset_index().rename(columns={'diff_minutes':'min_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_10=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'min'}).reset_index().rename(columns={'diff_minutes':'min_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_1_2022_VGL1376_11=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'mean'}).reset_index().rename(columns={'diff_minutes':'avg_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_12=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'mean'}).reset_index().rename(columns={'diff_minutes':'avg_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_13=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'mean'}).reset_index().rename(columns={'diff_minutes':'avg_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_1_2022_VGL1376_14=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'median'}).reset_index().rename(columns={'diff_minutes':'med_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_15=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'median'}).reset_index().rename(columns={'diff_minutes':'med_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_1_2022_VGL1376_16=trip_departure_1_1_2022_VGL1376[trip_departure_1_1_2022_VGL1376['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'median'}).reset_index().rename(columns={'diff_minutes':'med_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_1_2022_VGL1376_17=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no']).agg({'speed':'max'}).reset_index().rename(columns={'speed':'max_speed'})
trip_departure_1_1_2022_VGL1376_18=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no']).agg({'speed':'min'}).reset_index().rename(columns={'speed':'min_speed'})
trip_departure_1_1_2022_VGL1376_19=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no']).agg({'speed':'mean'}).reset_index().rename(columns={'speed':'avg_speed'})
trip_departure_1_1_2022_VGL1376_20=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no']).agg({'speed':'median'}).reset_index().rename(columns={'speed':'med_speed'})

trip_departure_1_1_2022_VGL1376_21=trip_departure_1_1_2022_VGL1376.groupby(['ope_date','bus_no']).agg({'is_completed':'sum'}).reset_index().rename(columns={'is_completed':'ttl_td_completed'})

trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_1,trip_departure_1_1_2022_VGL1376_2,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_3,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_4,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_5,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_6,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_7,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_8,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_9,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_10,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_11,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_12,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_13,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_14,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_15,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_16,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_17,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_18,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_19,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_20,how='left',on=['ope_date','bus_no'])
trip_departure_1_1_2022_VGL1376_int=pd.merge(trip_departure_1_1_2022_VGL1376_int,trip_departure_1_1_2022_VGL1376_21,how='left',on=['ope_date','bus_no'])

trip_departure_1_1_2022_VGL1376_int

'''
trip_departure_1_1_2022_VGL1376
# Out:
# C:\Users\izard\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#            td_id    ope_date  depot_id line_id captain_id   bus_no code_duty  \
# 443896  35073542  2022-01-31         2   T2010   YKUWLXKP  WVN5576       AM2
# 443897  35073543  2022-01-31         2   T2010   YKUWLXKP  WVN5576       AM2
# 443898  35073544  2022-01-31         2   T2010   YKUWLXKP  WVN5576       AM2
# 443899  35073545  2022-01-31         2   T2010   YKUWLXKP  WVN5576       AM2
# 443900  35073546  2022-01-31         2   T2010   YKUWLXKP  WVN5576       AM2
# 443901  35073547  2022-01-31         2   T2010   YKUWLXKP  WVN5576       AM2
# ...

# %%
#data model using sample data
pd.set_option('display.max_columns', None)

trip_departure_1_2022['dt_gps']=pd.to_datetime(trip_departure_1_2022['dt_gps'])
trip_departure_1_2022=trip_departure_1_2022.sort_values('dt_gps')
trip_departure_1_2022['diff_minutes']=pd.to_datetime(trip_departure_1_2022['dt_gps']).diff()/np.timedelta64(1, 'm')
trip_departure_1_2022['diff_label']=np.where((trip_departure_1_2022['dir']=='arrive')&(trip_departure_1_2022['direction']=='DIR2_arrive'),'to point a',np.nan)
trip_departure_1_2022['diff_label']=np.where((trip_departure_1_2022['dir']=='arrive')&(trip_departure_1_2022['direction']=='DIR1_arrive'),'from point a',trip_departure_1_2022['diff_label'])
trip_departure_1_2022['diff_label']=np.where((trip_departure_1_2022['dir']=='depart')&(trip_departure_1_2022['direction']=='DIR1_depart'),'idle mode',trip_departure_1_2022['diff_label'])
trip_departure_1_2022['diff_label']=np.where((trip_departure_1_2022['dir']=='depart')&(trip_departure_1_2022['direction']=='DIR2_depart'),'idle mode',trip_departure_1_2022['diff_label'])

trip_departure_1_2022_1=trip_departure_1_2022.groupby(['ope_date','bus_no'])[['td_id']].count().reset_index().rename(columns={'td_id':'ttl_td_id'}) # total trips on date
trip_departure_1_2022_2=trip_departure_1_2022.groupby(['ope_date','bus_no'])[['captain_id']].nunique().reset_index().rename(columns={'captain_id':'ttl_captain_id'}) # total captains on duty on date
trip_departure_1_2022_3=trip_departure_1_2022.groupby(['ope_date','bus_no'])[['point_a']].nunique().reset_index().rename(columns={'point_a':'ttl_point_a'}) # total point a of trip on date
trip_departure_1_2022_4=trip_departure_1_2022.groupby(['ope_date','bus_no'])[['point_b']].nunique().reset_index().rename(columns={'point_b':'ttl_point_b'}) # total point b of trip on date

trip_departure_1_2022_5=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'max'}).reset_index().rename(columns={'diff_minutes':'max_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_2022_6=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'max'}).reset_index().rename(columns={'diff_minutes':'max_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_2022_7=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'max'}).reset_index().rename(columns={'diff_minutes':'max_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_2022_8=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'min'}).reset_index().rename(columns={'diff_minutes':'min_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_2022_9=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'min'}).reset_index().rename(columns={'diff_minutes':'min_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_2022_10=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'min'}).reset_index().rename(columns={'diff_minutes':'min_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_2022_11=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'mean'}).reset_index().rename(columns={'diff_minutes':'avg_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_2022_12=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'mean'}).reset_index().rename(columns={'diff_minutes':'avg_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_2022_13=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'mean'}).reset_index().rename(columns={'diff_minutes':'avg_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_2022_14=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='from point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'median'}).reset_index().rename(columns={'diff_minutes':'med_diff_minutes_from_point_a'}).drop(columns=['diff_label'])
trip_departure_1_2022_15=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='idle mode'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'median'}).reset_index().rename(columns={'diff_minutes':'med_diff_minutes_idle_mode'}).drop(columns=['diff_label'])
trip_departure_1_2022_16=trip_departure_1_2022[trip_departure_1_2022['diff_label']=='to point a'].groupby(['ope_date','bus_no','diff_label']).agg({'diff_minutes':'median'}).reset_index().rename(columns={'diff_minutes':'med_diff_minutes_to_point_a'}).drop(columns=['diff_label'])

trip_departure_1_2022_17=trip_departure_1_2022.groupby(['ope_date','bus_no']).agg({'speed':'max'}).reset_index().rename(columns={'speed':'max_speed'})
trip_departure_1_2022_18=trip_departure_1_2022.groupby(['ope_date','bus_no']).agg({'speed':'min'}).reset_index().rename(columns={'speed':'min_speed'})
trip_departure_1_2022_19=trip_departure_1_2022.groupby(['ope_date','bus_no']).agg({'speed':'mean'}).reset_index().rename(columns={'speed':'avg_speed'})
trip_departure_1_2022_20=trip_departure_1_2022.groupby(['ope_date','bus_no']).agg({'speed':'median'}).reset_index().rename(columns={'speed':'med_speed'})

trip_departure_1_2022_21=trip_departure_1_2022.groupby(['ope_date','bus_no']).agg({'is_completed':'sum'}).reset_index().rename(columns={'is_completed':'ttl_td_completed'})

trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_1,trip_departure_1_2022_2,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_3,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_4,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_5,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_6,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_7,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_8,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_9,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_10,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_11,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_12,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_13,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_14,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_15,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_16,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_17,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_18,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_19,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_20,how='left',on=['ope_date','bus_no'])
trip_departure_1_2022_int=pd.merge(trip_departure_1_2022_int,trip_departure_1_2022_21,how='left',on=['ope_date','bus_no'])

trip_departure_1_2022_int
# Out:
#          ope_date   bus_no  ttl_td_id  ttl_captain_id  ttl_point_a  \
# 0      2022-01-01  CDD1422         36               1            1
# 1      2022-01-01  CDD1425         32               1            1
# 2      2022-01-01  CDH2336         32               1            1
# 3      2022-01-01  CDH2346         44               1            1
# 4      2022-01-01  CDH5963         46               2            1
# ...           ...      ...        ...             ...          ...
# 15753  2022-01-31  WVN5576         22               2            1
# 15754  2022-01-31  WVN5617         24               2            1
# 15755  2022-01-31  WVN5644          8               1            1
# 15756  2022-01-31  WVP2462         66               2            1
# 15757  2022-01-31  WVP2491         20               1            1
#
#        ttl_point_b  max_diff_minutes_from_point_a  max_diff_minutes_idle_mode  \
# 0                1                       0.266667                    0.200000
# ...

# %%
trip_departure_1_2022_int.corr()
# Out:
#                                ttl_td_id  ttl_captain_id  ttl_point_a  \
# ttl_td_id                       1.000000        0.339681    -0.035242
# ttl_captain_id                  0.339681        1.000000     0.118695
# ttl_point_a                    -0.035242        0.118695     1.000000
# ttl_point_b                    -0.046019        0.126623     0.835925
# max_diff_minutes_from_point_a   0.107789        0.141678     0.032967
# max_diff_minutes_idle_mode     -0.007806        0.037689    -0.008310
# max_diff_minutes_to_point_a     0.084319        0.058051     0.002959
# min_diff_minutes_from_point_a  -0.291475       -0.148762    -0.010568
# min_diff_minutes_idle_mode     -0.106721       -0.060973    -0.002943
# min_diff_minutes_to_point_a    -0.300480       -0.161396    -0.008468
# avg_diff_minutes_from_point_a  -0.008218        0.083582     0.028180
# avg_diff_minutes_idle_mode     -0.016002        0.033926    -0.008388
# ...
