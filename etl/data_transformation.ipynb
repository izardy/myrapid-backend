# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
from datetime import datetime,timedelta
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Info Depot

# %%
infoDepot=pd.read_csv('../data/processed/InfoDEPOT.csv')
infoDepot['depot_name']=infoDepot['depot_name'].str.strip()
infoDepot['state']=infoDepot['state'].str.strip()
infoDepot['zone']=infoDepot['zone'].str.strip()
infoDepot['code']=infoDepot['code'].str.strip()
infoDepot['route_desc']=infoDepot['route_desc'].str.strip()
infoDepot['distance']=infoDepot['distance'].str.replace(",","").str.strip().astype(float)
infoDepot['stop_name']=infoDepot['stop_name'].str.strip()
infoDepot['street_name']=infoDepot['street_name'].str.strip()

infoDepot['geopoint']=infoDepot['latitude'].astype(str)+','+infoDepot['longitude'].astype(str)

#infoDepot['geolocation']=gpd.points_from_xy(infoDepot['latitude'], infoDepot['longitude'])
#gdf = gpd.GeoDataFrame(infoDepot, geometry=gpd.points_from_xy(infoDepot.latitude, infoDepot.longitude)) 

#infoDepot.to_file("../data/processed/json/infoDepot.json", driver="GeoJSON")
#gdf.to_file("infoDepot.json", driver="GeoJSON")

infoDepot=infoDepot.to_json(orient = "records")
#infoDepot.to_csv('infoDepot2.csv',index=False)
with open('../data/processed/json/infoDepot.json', 'w') as f:
    f.write(infoDepot)

# run once to create solr collection infoDepot /home/hadoop/solr-9.3.0/bin/solr create -c infoDepot
#os.system('/home/hadoop/solr-9.3.0/bin/solr create -c infoDepot')

# run once to post data into infoDepot collection /home/hadoop/solr-9.3.0/bin/post -c infoDepot /home/hadoop/MyRapidHack2023-BackEnd/data/processed/json/infoDepot.json
os.system('/home/hadoop/solr-9.3.0/bin/post -c infoDepot /home/hadoop/MyRapidHack2023-BackEnd/data/processed/json/infoDepot.json')
# Out:
# 1

# %%
infoDepot
# Out:
#        depot_id depot_name                  state zone code  route_id  \
# 0             1     Sentul  Selangor/Kuala Lumpur  RKL  STL       1.0
# 1             1     Sentul  Selangor/Kuala Lumpur  RKL  STL       2.0
# 2             1     Sentul  Selangor/Kuala Lumpur  RKL  STL       3.0
# 3             1     Sentul  Selangor/Kuala Lumpur  RKL  STL       4.0
# 4             1     Sentul  Selangor/Kuala Lumpur  RKL  STL       5.0
# ...         ...        ...                    ...  ...  ...       ...
# 14890        28  Putrajaya  Selangor/Kuala Lumpur  RKL  PTJ    1123.0
# 14891        28  Putrajaya  Selangor/Kuala Lumpur  RKL  PTJ    1123.0
# 14892        28  Putrajaya  Selangor/Kuala Lumpur  RKL  PTJ    1123.0
# 14893        28  Putrajaya  Selangor/Kuala Lumpur  RKL  PTJ    1123.0
# 14894        28  Putrajaya  Selangor/Kuala Lumpur  RKL  PTJ    1123.0
#
#                                  route_desc  bus_stop_id  distance  \
# 0      TITIWANGSA - BKT BINTANG via KG BARU          NaN       NaN
# 1                       KL SENTRAL - MALURI          NaN       NaN
# 2              MALURI - TITIWANGSA via KLCC          NaN       NaN
# 3                JLN SULTAN MOHD - PARLIMEN          NaN       NaN
# 4             PINGGIRAN BT CAVES - CHOW KIT          NaN       NaN
# ...                                     ...          ...       ...
# 14890         Presint 11 ~ Dataran Gemilang      11744.0   13108.0
# 14891         Presint 11 ~ Dataran Gemilang      11745.0   13278.0
# 14892         Presint 11 ~ Dataran Gemilang      11746.0   13552.0
# 14893         Presint 11 ~ Dataran Gemilang      11747.0   20543.0
# 14894         Presint 11 ~ Dataran Gemilang      11680.0   20700.0
#
#                                              stop_name  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 14890        PPJ33 KEMENTERIAN PEMBANGUNAN LUAR BANDAR
# 14891                           PPJ34 DATARAN GEMILANG
# 14892                           PPJ37 DATARAN GEMILANG
# 14893  PPJ38 KEMENTERIAN PEMBANGUNAN LUAR BANDAR (OPP)
# 14894                     PPJ132 APARTMENT PRESINT 11B
#
#                   street_name  latitude   longitude            geolocation
# 0                         NaN       NaN         NaN            POINT EMPTY
# 1                         NaN       NaN         NaN            POINT EMPTY
# 2                         NaN       NaN         NaN            POINT EMPTY
# 3                         NaN       NaN         NaN            POINT EMPTY
# 4                         NaN       NaN         NaN            POINT EMPTY
# ...                       ...       ...         ...                    ...
# 14890       PERSIARAN PERDANA  2.904778  101.681029  POINT (2.905 101.681)
# 14891  LINGKARAN GEMILANG DUA  2.903404  101.681176  POINT (2.903 101.681)
# 14892  LINGKARAN GEMILANG DUA  2.903986  101.679528  POINT (2.904 101.680)
# 14893       PERSIARAN PERDANA  2.904962  101.680463  POINT (2.905 101.680)
# 14894              JALAN P11B  2.957192  101.676781  POINT (2.957 101.677)
#
# [14895 rows x 14 columns]

# %%
infoBas.columns
# Out:
# Index(['ope_date', 'depot_id', 'line_id', 'bus_no', 'point_a', 'point_b',
#        'ttl_td_id', 'ttl_captain_id', 'ttl_point_a', 'ttl_point_b',
#        'max_diff_minutes_from_point_a', 'max_diff_minutes_idle_mode',
#        'max_diff_minutes_to_point_a', 'min_diff_minutes_from_point_a',
#        'min_diff_minutes_idle_mode', 'min_diff_minutes_to_point_a',
#        'avg_diff_minutes_from_point_a', 'avg_diff_minutes_idle_mode',
#        'avg_diff_minutes_to_point_a', 'med_diff_minutes_from_point_a',
#        'med_diff_minutes_idle_mode', 'med_diff_minutes_to_point_a',
#        'max_speed', 'min_speed', 'avg_speed', 'med_speed', 'ttl_td_completed',
#        'br_id', 'br_repair_status', 'br_entry_status', 'br_date',
#        'br_date_entry', 'br_target_completed', 'br_ttl_days', 'rtd_id',
#        'rtd_date', 'route_id', 'bus_model_id', 'driver_id', 'rtd_cause',
#        'cause_remark', 'fc_remark', 'date_issues', 'capt_id', 'bcc_acc_id',
#        'acc_date', 'bus_damage', 'eng_find', 'label'],
#       dtype='object')

# %% [markdown]
# ### Info Bas

# %%
infoTRIP=pd.read_csv('../data/trip_departure/processed/td_agg.csv')
infoTRIP['ope_date']=pd.to_datetime(infoTRIP['ope_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')

infoBas=pd.read_csv('../data/processed/InfoBAS.csv')

infoBas['ope_date']=pd.to_datetime(infoBas['ope_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoBas['br_date']=pd.to_datetime(infoBas['br_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoBas['br_date_entry']=pd.to_datetime(infoBas['br_date_entry']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoBas['br_target_completed']=pd.to_datetime(infoBas['br_target_completed']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoBas['rtd_date']=pd.to_datetime(infoBas['rtd_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoBas['date_issues']=pd.to_datetime(infoBas['date_issues']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoBas['acc_date']=pd.to_datetime(infoBas['acc_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')

infoBas=infoBas.drop(columns=['label_1','label_2','label_3'])

infoBas=pd.merge(infoTRIP,infoBas,how='left',on=['ope_date','depot_id','line_id','bus_no']).drop_duplicates()

infoBas=infoBas.to_json(orient = "records")

with open('../data/processed/json/infoBas.json', 'w') as f:
    f.write(infoBas)

# run once to create solr collection infoBas /home/hadoop/solr-9.3.0/bin/solr create -c infoBas
#os.system('/home/hadoop/solr-9.3.0/bin/solr create -c infoBAS')

# run once to post data into infoBas collection /home/hadoop/solr-9.3.0/bin/post -c infoDepot /home/hadoop/MyRapidHack2023-BackEnd/data/processed/json/infoBas.json
os.system('/home/hadoop/solr-9.3.0/bin/post -c infoDepot /home/hadoop/MyRapidHack2023-BackEnd/data/processed/json/infoBAS.json')
# Out:
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                   ope_date  depot_id line_id   bus_no              point_a  \
# 0      2022-10-01 00:00:00        10   K1000  CDH7753             H/BANDAR
# 1      2022-10-01 00:00:00        10   K1000  CDD1442             H/BANDAR
# 2      2022-10-01 00:00:00        10   K1000  CDH2338             H/BANDAR
# 3      2022-10-01 00:00:00        10   K1000  CDH5966             H/BANDAR
# 4      2022-10-01 00:00:00        10   K1000  CDH7750             H/BANDAR
# ...                    ...       ...     ...      ...                  ...
# 13924  2022-10-21 00:00:00         5   U5900   WB759L  BANDAR SUNGAI LONG
# 13925  2022-10-21 00:00:00         5   U4000  WA1376G       DAMAI PERDANA
# 13926  2022-10-21 00:00:00         5   U6500  WPV6981  KL Santral (Petron)
# 13927  2022-10-21 00:00:00         2   U1910  WUX5671       SRI SEGAMBIUT
# 13928  2022-10-21 00:00:00         2   U1910  WUW8426       SRI SEGAMBIUT
#
#                     point_b  ttl_td_id  ttl_captain_id  ttl_point_a  \
# 0            GAMBANG RESORT         14               1            1
# 1            GAMBANG RESORT         12               1            1
# 2            GAMBANG RESORT         12               1            1
# 3            GAMBANG RESORT         12               1            1
# 4            GAMBANG RESORT          8               1            1
# ...                     ...        ...             ...          ...
# 13924            LEBUH PUDU         16               1            1
# 13925  HUB LEBUH PUDU via B         10               1            1
# 13926            Pasar Seni         32               1            1
# 13927             CHOW KIT          43               2            1
# 13928             CHOW KIT          48               2            1
#
#        ttl_point_b  max_diff_minutes_from_point_a  max_diff_minutes_idle_mode  \
# 0                1                      84.533333                  102.900000
# 1                1                     158.950000                   46.250000
# 2                1                      83.283333                  104.966667
# 3                1                      79.983333                  103.183333
# 4                1                     114.933333                   47.083333
# ...            ...                            ...                         ...
# 13924            1                     119.000000                   76.500000
# 13925            1                      70.216667                   60.816667
# 13926            1                       8.500000                   54.050000
# 13927            1                      33.000000                   44.016667
# 13928            1                      39.000000                   28.983333
#
#        max_diff_minutes_to_point_a  min_diff_minutes_from_point_a  \
# 0                        80.500000                      63.883333
# 1                       106.600000                      45.866667
# 2                        80.116667                      78.750000
# 3                        83.833333                      75.650000
# 4                        97.566667                      73.833333
# ...                            ...                            ...
# 13924                   112.983333                      66.483333
# 13925                   120.283333                      56.366667
# 13926                    98.483333                       5.000000
# 13927                    43.483333                      26.500000
# 13928                    36.500000                      25.000000
#
#        min_diff_minutes_idle_mode  min_diff_minutes_to_point_a  \
# 0                       29.100000                    44.116667
# 1                        3.800000                    76.750000
# 2                       34.916667                    39.366667
# 3                       33.933333                    55.900000
# 4                        6.433333                    75.033333
# ...                           ...                          ...
# 13924                    1.000000                    67.500000
# 13925                    0.000000                    73.850000
# 13926                    0.500000                    58.000000
# 13927                    2.000000                    26.983333
# 13928                    2.500000                    27.500000
#
#        avg_diff_minutes_from_point_a  avg_diff_minutes_idle_mode  \
# 0                          73.233333                   61.783333
# 1                          92.727778                   32.366667
# 2                          81.766667                   57.560000
# 3                          77.433333                   53.123333
# 4                          94.383333                   24.000000
# ...                              ...                         ...
# 13924                      82.495833                   29.302381
# 13925                      63.291667                   18.900000
# 13926                       5.875000                   13.816667
# 13927                      29.450000                   14.519048
# 13928                      30.827778                   13.479710
#
#        avg_diff_minutes_to_point_a  med_diff_minutes_from_point_a  \
# 0                        68.311111                      72.258333
# 1                        88.500000                      73.366667
# 2                        60.505556                      83.266667
# 3                        70.572222                      76.666667
# 4                        86.300000                      94.383333
# ...                            ...                            ...
# 13924                    82.491667                      72.250000
# 13925                    89.827778                      63.291667
# 13926                    70.683333                       5.500000
# 13927                    33.007576                      29.250000
# 13928                    32.330556                      30.750000
#
#        med_diff_minutes_idle_mode  med_diff_minutes_to_point_a  max_speed  \
# 0                       57.675000                    80.316667       28.0
# 1                       41.483333                    82.150000       56.0
# 2                       51.216667                    62.033333       59.0
# 3                       44.350000                    71.983333       45.0
# 4                       18.483333                    86.300000       56.0
# ...                           ...                          ...        ...
# 13924                    8.500000                    74.741667       46.0
# 13925                    7.391667                    75.350000       35.0
# 13926                    3.500000                    69.241667       24.0
# 13927                    7.500000                    33.000000       38.0
# 13928                    8.500000                    31.250000       41.0
#
#        min_speed  avg_speed  med_speed  ttl_td_completed      br_id  \
# 0            8.0  16.181818       15.0              14.0        NaN
# 1           15.0  24.090909       19.0              12.0        NaN
# 2            8.0  21.777778       17.0              12.0        NaN
# 3            8.0  17.083333       14.0              12.0  1129191.0
# 4            6.0  21.285714       16.0               8.0  1129194.0
# ...          ...        ...        ...               ...        ...
# 13924        1.0  25.142857       29.0              16.0        NaN
# 13925        4.0  14.700000       13.0              10.0        NaN
# 13926        1.0  11.611111       11.5              32.0        NaN
# 13927        1.0  15.846154       13.0              43.0        NaN
# 13928        1.0  15.617647       15.5              48.0        NaN
#
#       br_repair_status             br_entry_status              br_date  \
# 0                  NaN                         NaN                  NaN
# 1                  NaN                         NaN                  NaN
# 2                  NaN                         NaN                  NaN
# 3                MAJOR  BAS MENYENTAP MASA MEMANDU  2022-10-01 00:00:00
# 4               SCH.PM                    SERVIS A  2022-10-01 00:00:00
# ...                ...                         ...                  ...
# 13924              NaN                         NaN                  NaN
# 13925              NaN                         NaN                  NaN
# 13926              NaN                         NaN                  NaN
# 13927              NaN                         NaN                  NaN
# 13928              NaN                         NaN                  NaN
#
#              br_date_entry  br_target_completed  br_ttl_days  rtd_id rtd_date  \
# 0                      NaN                  NaN          NaN     NaN      NaN
# 1                      NaN                  NaN          NaN     NaN      NaN
# 2                      NaN                  NaN          NaN     NaN      NaN
# 3      2022-10-01 00:00:00  2022-10-02 00:00:00          1.0     NaN      NaN
# 4      2022-10-01 00:00:00  2022-10-02 00:00:00          1.0     NaN      NaN
# ...                    ...                  ...          ...     ...      ...
# 13924                  NaN                  NaN          NaN     NaN      NaN
# 13925                  NaN                  NaN          NaN     NaN      NaN
# 13926                  NaN                  NaN          NaN     NaN      NaN
# 13927                  NaN                  NaN          NaN     NaN      NaN
# 13928                  NaN                  NaN          NaN     NaN      NaN
#
#        route_id  bus_model_id driver_id  rtd_cause cause_remark fc_remark  \
# 0           NaN           NaN       NaN        NaN          NaN       NaN
# 1           NaN           NaN       NaN        NaN          NaN       NaN
# 2           NaN           NaN       NaN        NaN          NaN       NaN
# 3           NaN           NaN       NaN        NaN          NaN       NaN
# 4           NaN           NaN       NaN        NaN          NaN       NaN
# ...         ...           ...       ...        ...          ...       ...
# 13924       NaN           NaN       NaN        NaN          NaN       NaN
# 13925       NaN           NaN       NaN        NaN          NaN       NaN
# 13926       NaN           NaN       NaN        NaN          NaN       NaN
# 13927       NaN           NaN       NaN        NaN          NaN       NaN
# 13928       NaN           NaN       NaN        NaN          NaN       NaN
#
#                date_issues capt_id  bcc_acc_id acc_date bus_damage eng_find  \
# 0                      NaN     NaN         NaN      NaN        NaN      NaN
# 1                      NaN     NaN         NaN      NaN        NaN      NaN
# 2                      NaN     NaN         NaN      NaN        NaN      NaN
# 3      2022-10-01 00:00:00     NaN         NaN      NaN        NaN      NaN
# 4      2022-10-01 00:00:00     NaN         NaN      NaN        NaN      NaN
# ...                    ...     ...         ...      ...        ...      ...
# 13924                  NaN     NaN         NaN      NaN        NaN      NaN
# 13925                  NaN     NaN         NaN      NaN        NaN      NaN
# 13926                  NaN     NaN         NaN      NaN        NaN      NaN
# 13927                  NaN     NaN         NaN      NaN        NaN      NaN
# 13928                  NaN     NaN         NaN      NaN        NaN      NaN
#
#                label
# 0        normal trip
# 1        normal trip
# 2        normal trip
# 3      engine repair
# 4      engine repair
# ...              ...
# 13924    normal trip
# 13925    normal trip
# 13926    normal trip
# 13927    normal trip
# 13928    normal trip
#
# [13929 rows x 49 columns]

# %% [markdown]
# ### Info Captain

# %%
infoDepot=pd.read_csv('../data/processed/InfoDEPOT.csv')[['depot_id','depot_name','route_id','route_desc']].drop_duplicates()#

infoCaptain=pd.read_csv('../data/captain_schedule/processed/infoCAPTAIN.csv')

infoCaptain=pd.merge(infoCaptain,infoDepot,how='left',on=['depot_id','route_id']).head(10)#

infoCaptain['cs_date']=pd.to_datetime(infoCaptain['cs_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')
infoCaptain['ope_date']=pd.to_datetime(infoCaptain['ope_date']+ ' 00:00:00').dt.strftime('%Y-%m-%d %H:%M:%S')

infoCaptain=infoCaptain.rename(columns={'dt_gps_max':'dt_endduty','dt_gps_min':'dt_startduty'})
'''
infoCaptain=infoCaptain.to_json(orient = "records")



with open('../data/processed/json/infoCaptain.json', 'w') as f:
    f.write(infoCaptain)

# run once to create solr collection infoCaptain /home/hadoop/solr-9.3.0/bin/solr create -c infoCaptain
# os.system('/home/hadoop/solr-9.3.0/bin/solr create -c infoCaptain')

# run once to post data into infoCaptain collection /home/hadoop/solr-9.3.0/bin/post -c infoCaptain /home/hadoop/MyRapidHack2023-BackEnd/data/processed/json/infoCaptain.json
os.system('/home/hadoop/solr-9.3.0/bin/post -c infoCaptain /home/hadoop/MyRapidHack2023-BackEnd/data/processed/json/infoCaptain.json')
'''
infoCaptain
# Out:
#   cs_captain_id   bus_no  depot_id  route_id              cs_date  \
# 0      VNNTUGYM  VAH9042        21       681  2022-10-01 00:00:00
# 1      ZFRXTOSA  VAH9042        21       681  2022-10-01 00:00:00
# 2      SHGYQRDN   VH1579        21       801  2022-10-01 00:00:00
# 3      TFNZBHEA  VAJ2875        21       801  2022-10-01 00:00:00
# 4      JMOJOCJA   VH1579        21       801  2022-10-01 00:00:00
# 5      FZZRKLJR  VAJ2875        21       801  2022-10-01 00:00:00
# 6      MLMDBXYO  VAJ8965        21       685  2022-10-01 00:00:00
# 7      RYNZSKUW   VG8591        21       683  2022-10-01 00:00:00
# 8      FYLMXHEL   VG8794        21       683  2022-10-01 00:00:00
# 9      ALGZZZTY   VG8654        21       683  2022-10-01 00:00:00
#
#        cs_startat cs_endat cs_startduty cs_endduty  cs_totaltrip  \
# 0    MRT Sg.Buloh      NaN     05:00:00   15:00:00            12
# 1    MRT Sg.Buloh      NaN     13:55:00   00:30:00            13
# 2    MRT Sg.Buloh      NaN     04:55:00   15:05:00             7
# 3    MRT Sg.Buloh      NaN     05:30:00   15:45:00             7
# 4    MRT Sg.Buloh      NaN     14:25:00   00:15:00             7
# 5    MRT Sg.Buloh      NaN     14:45:00   00:55:00             7
# 6  MRT Kg.Selamat      NaN     05:10:00   15:35:00            14
# 7    MRT Sg.Buloh      NaN     05:10:00   15:15:00             6
# 8    MRT Sg.Buloh      NaN     05:40:00   15:45:00             6
# 9    MRT Sg.Buloh      NaN     06:10:00   20:55:00             9
#
#    minutes_plan dt_captain_id  ope_date dt_endduty dt_startduty  dt_totaltrip  \
# 0           600           NaN       NaN        NaN          NaN           NaN
# 1           635           NaN       NaN        NaN          NaN           NaN
# 2           610           NaN       NaN        NaN          NaN           NaN
# 3           615           NaN       NaN        NaN          NaN           NaN
# 4           590           NaN       NaN        NaN          NaN           NaN
# 5           610           NaN       NaN        NaN          NaN           NaN
# 6           625           NaN       NaN        NaN          NaN           NaN
# 7           605           NaN       NaN        NaN          NaN           NaN
# 8           605           NaN       NaN        NaN          NaN           NaN
# 9           885           NaN       NaN        NaN          NaN           NaN
#
#    minutes_actual        depot_name  \
# 0             NaN  MRT Sungai Buloh
# 1             NaN  MRT Sungai Buloh
# 2             NaN  MRT Sungai Buloh
# 3             NaN  MRT Sungai Buloh
# 4             NaN  MRT Sungai Buloh
# 5             NaN  MRT Sungai Buloh
# 6             NaN  MRT Sungai Buloh
# 7             NaN  MRT Sungai Buloh
# 8             NaN  MRT Sungai Buloh
# 9             NaN  MRT Sungai Buloh
#
#                                         route_desc
# 0  MRT SUNGAI BULOH - MASJID HOSPITAL SUNGAI BULOH
# 1  MRT SUNGAI BULOH - MASJID HOSPITAL SUNGAI BULOH
# 2            MRT SUNGAI BULOH - TAMAN IMPIAN INDAH
# 3            MRT SUNGAI BULOH - TAMAN IMPIAN INDAH
# 4            MRT SUNGAI BULOH - TAMAN IMPIAN INDAH
# 5            MRT SUNGAI BULOH - TAMAN IMPIAN INDAH
# 6      MRT KAMPUNG SELAMAT - KAMPUNG BARU SG BULOH
# 7                    MRT SUNGAI BULOH - AMAN PUTRI
# 8                    MRT SUNGAI BULOH - AMAN PUTRI
# 9                    MRT SUNGAI BULOH - AMAN PUTRI

# %% [markdown]
# ### Info Trip

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937495 entries, 0 to 937494
# Data columns (total 17 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   cs_captain_id   937495 non-null  object
#  1   bus_no          794165 non-null  object
#  2   depot_id        937495 non-null  int64
#  3   route_id        937495 non-null  int64
#  4   cs_date         937495 non-null  object
#  5   cs_startat      937333 non-null  object
#  6   cs_endat        706163 non-null  object
#  7   cs_startduty    937495 non-null  object
#  8   cs_endduty      937495 non-null  object
#  9   cs_totaltrip    937495 non-null  int64
#  10  minutes_plan    937495 non-null  int64
#  11  dt_captain_id   469673 non-null  object
#  12  ope_date        469673 non-null  object
#  13  dt_endduty      469673 non-null  object
#  14  dt_startduty    469673 non-null  object
#  15  dt_totaltrip    469673 non-null  float64
#  16  minutes_actual  469673 non-null  float64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 121.6+ MB
