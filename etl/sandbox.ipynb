# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
pd.read_csv('../data/accident.csv') # lat lon accident to plot
# Out:
#       bcc_acc_id    acc_date      time_report       event_time  \
# 0          14686  2022-01-01  0 days 07:23:00  0 days 07:19:00
# 1          14688  2022-01-01  0 days 08:30:00  0 days 08:30:00
# 2          14689  2022-01-02  0 days 07:30:00  0 days 07:00:00
# 3          14690  2022-01-03  0 days 09:47:00  0 days 09:45:00
# 4          14691  2022-01-03  0 days 14:36:00  0 days 14:30:00
# ...          ...         ...              ...              ...
# 2251       16948  2023-06-30  0 days 06:25:00  0 days 06:00:00
# 2252       16949  2023-06-30  0 days 08:51:00  0 days 08:49:00
# 2253       16950  2023-06-30  0 days 12:54:00  0 days 12:19:00
# 2254       16951  2023-06-30  0 days 15:06:00  0 days 15:00:00
# 2255       16952  2023-06-30  0 days 23:30:00  0 days 22:35:00
#
#                                               event_loc  location_cat  \
# 0                     HADAPAN BALAI POLIS PEKAN AI ITAM           3.0
# 1                                        JALAN BESERAH            3.0
# 2     Bus Stop Guan ying temple, Jalan Pahang (OD: L...           3.0
# 3           JALAN TELUK KUMBAR- HADAPAN SJKC YANG CHENG           2.0
# 4     Jalan Raja Laut hala Dato Senu (OD: PASAR SENI...           3.0
# ...                                                 ...           ...
# 2251                       MRT FEEDER BUS KAJANG DEPOT            1.0
# 2252                                     KAMPUNG PISANG           3.0
# 2253  Berhampiran Winnie Plaza Jalan Sg.Chua (OD : B...           3.0
# 2254               PEKAN AIR ITAM- BERHADAPAN 7-ELEVEN            3.0
# 2255          LAMPU ISYARAT SIMPANG BALAK, JALAN CHERAS           3.0
#
#        bus_no body_no  bus_model_id  route_id  depot_id   capt_id  \
# 0     PJJ7237       -            26       238        12  KTATUPUK
# 1     CDH7746     NaN            13       227        10  FWNVJNSM
# 2     WUW1702    L205             2       877         2  BTYCWGIS
# 3     PJG4312       -            26       263        14  FOXUZEQW
# 4     WVC4291    L288             2       874         2  VTZFMSRN
# ...       ...     ...           ...       ...       ...       ...
# 2251   VX3625     NaN            25       805        22  JWEDCNVZ
# 2252  PKX3372       -            13       238        12  HBFXIBCN
# 2253   WB915L    S731            10       598         5  ERXHQQHN
# 2254  PLV1635       -            10       235        12  BXIANLKH
# 2255   VK2745     NaN            25       770        22  CUCFPFKN
#
#                third_party  cat_id  injury  third_party2 spad_case  \
# 0         KERETA - PMW5076       7     NaN           NaN        NO
# 1                      NaN       8     NaN           NaN        NO
# 2       Motorsikal BQS2858       4     NaN           NaN        NO
# 3     LORI TANAH - PHJ9211       7     NaN           NaN        NO
# 4                      NaN       8     NaN           NaN        NO
# ...                    ...     ...     ...           ...       ...
# 2251                   NaN       7     NaN           NaN        NO
# 2252                   NaN       8     NaN           NaN        NO
# 2253                   NaN       8     NaN           NaN        NO
# 2254                   NaN       7     NaN           NaN        NO
# 2255                   NaN       7     NaN           NaN        NO
#
#                                              bus_damage  immediate_cause  \
# 0                    TIADA KEROSAKAN / TIADA KECEDERAAN              3.0
# 1                                     CERMIN SISI PECAH              1.0
# 2                           Bumper belakang kanan pecah              3.0
# 3     BUCU BELAKANG SEBELAH KANAN PECAH / TIADA KECE...              3.0
# 4                  Cermin pintu penumpang hadapan pecah              1.0
# ...                                                 ...              ...
# 2251   BAHAGIAN CERMIN BELAKANG SEBELAH KANAN BAS PECAH              4.0
# 2252                                    TIADA KEROSAKAN              5.0
# 2253               Cermin pintu penumpang hadapan pecah              1.0
# 2254              CALAR DIBAHAGIAN BODY BELAKANG KANAN               2.0
# 2255    BAHAGIAN BELAKANG BADAN BAS SEBELAH KANAN CALAR              2.0
#
#                                                 catitan  \
# 0                           SEBUAH KERETA MELANGGAR BAS
# 1          TERLANGGAR DAHAN POKOK TUMBANG DI ATAS JALAN
# 2                                  Dilanggar motorsikal
# 3                             SEBUAH LORI MELANGGAR BAS
# 4              Bas dibaling objek keras oleh orang awam
# ...                                                 ...
# 2251  BAS DILANGGAR BAS MRT KAJANG (VX3035) KETIKA B...
# 2252  SEORANG PENUMPANG PEREMPUAN TERJATUH DI DALAM BAS
# 2253                          Tergesel penghadang jalan
# 2254                                                  -
# 2255  BAS MELANGGAR KERETA PERODUA BEZZA (QLB4026) K...
#
#                                                  remark  pax  public  staff  \
# 0     SEBUAH KERETA YANG HENDAK KELUAR DARI PARKING ...    0       0      0
# 1                                                   NaN    0       0      0
# 2     Semasa BC sedang menurunkan penumpang, tiba-ti...    0      26      0
# 3     SEBUAH LORI TELAH MENLANGGAR BELAKANG BAS KETI...    0       0      0
# 4     Semasa kejadian terdapat 8 orang penumpang di ...    0       0      0
# ...                                                 ...  ...     ...    ...
# 2251  BAS DILANGGAR BAS MRT KAJANG (VX3035) KETIKA B...    0       0      0
# 2252  SEORANG PENUMPANG PEREMPUAN DALAM LINGKUNGAN U...   20       0      0
# 2253  Laporan awal dari kapten memaklumkan semasa se...    0       0      0
# 2254  INFO DARI BC SEMASA DALAM PERJALANAN DI PEKAN ...    0       0      0
# 2255  BAS MELANGGAR KERETA PERODUA BEZZA (QLB4026) K...    0       0      0
#
#       status report_date  guilty  penalty         cost  act_taken  \
# 0          1  2022-01-01       0        6          NIL        7.0
# 1          1  2022-01-01       0        1      RM95.00        1.0
# 2          1  2022-01-02       0        6     RM362.17        7.0
# 3          1  2022-01-03       0        6    RM2680.61        7.0
# 4          1  2022-01-03       0        6     RM546.00        7.0
# ...      ...         ...     ...      ...          ...        ...
# 2251       1  2023-06-30       0        1     RM938.11        1.0
# 2252       1  2023-06-30       0        6            0        7.0
# 2253       1  2023-06-30       2        1  RM 8,700.99        3.0
# 2254       1  2023-06-30       0        6     RM364.51        7.0
# 2255       1  2023-06-30       2        1     RM517.01        1.0
#
#                           cso_duty category_acc             acc_sn  \
# 0       MOHAMAD MAZIKI BIN KHAZALI        MINOR  ACC12220101S70001
# 1              NUR NADILA MOHD NOR        MINOR  ACC10220101SK5003
# 2     NORKHATINA BINTI MOHD RAZALI        MINOR  ACC02220102KLG001
# 3             ABD RAHMAN BIN AHMAD        MINOR  ACC14220103S70001
# 4     NORKHATINA BINTI MOHD RAZALI        MINOR  ACC02220103KLG002
# ...                            ...          ...                ...
# 2251      MUHAMAD AFIQ BIN RAZALI         MINOR  ACC22230630S5M002
# 2252    THAVABALAN A/L LOHGANATHAN        MINOR  ACC12230630SK5003
# 2253       NOR AQILAH BINTI KHAMIS        MINOR  ACC05230630S5A004
# 2254    MUHAMMAD AMIRUL BIN MAZLAN        MINOR  ACC12230630S5A005
# 2255                ROSLINDA JUPRI        MINOR  ACC22230630S5M006
#
#                                           telegram_desc  fin_impact  \
# 0                                                   NaN         0.0
# 1                                                   NaN         0.0
# 2                                                   NaN         NaN
# 3                                                   NaN         0.0
# 4     Cermin pintu penumpang hadapan pecah\r\n\r\nSe...         NaN
# ...                                                 ...         ...
# 2251   BAHAGIAN CERMIN BELAKANG SEBELAH KANAN BAS PECAH         0.0
# 2252  SEORANG PENUMPANG PEREMPUAN DALAM LINGKUNGAN U...         0.0
# 2253  Cermin pintu penumpang hadapan pecah\r\n\r\nLa...         0.0
# 2254  INFO DARI BC SEMASA DALAM PERJALANAN DI PEKAN ...         0.0
# 2255  BAHAGIAN BELAKANG BADAN BAS SEBELAH KANAN CALA...         0.0
#
#       ope_impact                                           ops_find  \
# 0            1.0                              BC Tidak Bersalah\r\n
# 1            1.0  Siasatan telah dilakukan keatas kapten pada 05...
# 2            NaN       kecuaian pihak ketiga menyebabkan kemalangan
# 3            1.0                              BC Tidak Bersalah\r\n
# 4            NaN  Tiada kecuaian dari kapten bas dan suspect yan...
# ...          ...                                                ...
# 2251         1.0  HASIL SIASATAN YANG DIJALANKAN PIHAK DEPOH MEN...
# 2252         1.0                                      Bc not guilty
# 2253         1.0  Hasail siasatan dari rakaman CCTV di dapati BC...
# 2254         1.0  Bc not guilty - Tiada saman dikeluarkan oleh P...
# 2255         1.0  HASIL SIASATAN YANG DIJALANKAN PIHAK DEPOH MEN...
#
#                         eng_find  conclusion_close  accstatus  \
# 0     Non mechanical failure\r\n               2.0        1.0
# 1                            NaN               2.0        1.0
# 2         non mechanical failure               2.0        1.0
# 3     Non mechanical failure\r\n               2.0        1.0
# 4         non mechanical failure               2.0        1.0
# ...                          ...               ...        ...
# 2251                         NaN               2.0        1.0
# 2252     Non mechanical faillure               2.0        1.0
# 2253                         NaN               2.0        1.0
# 2254     Non mechanical faillure               2.0        1.0
# 2255                         NaN               2.0        1.0
#
#                dt_created          dt_modified  modified_by
# 0     2022-01-01 07:37:29  2022-08-09 16:02:54          NaN
# 1     2022-01-01 10:08:42  2023-08-01 17:15:34          NaN
# 2     2022-01-02 07:44:20  2022-08-02 16:21:26          NaN
# 3     2022-01-03 09:58:50  2022-08-09 16:21:32          NaN
# 4     2022-01-03 14:51:32  2022-08-02 16:17:03          NaN
# ...                   ...                  ...          ...
# 2251  2023-06-30 06:54:03  2023-07-13 18:14:50          NaN
# 2252  2023-06-30 09:22:11  2023-07-20 12:30:32          NaN
# 2253  2023-06-30 12:54:24  2023-07-21 09:26:13          NaN
# 2254  2023-06-30 15:27:06  2023-07-04 11:07:14          NaN
# 2255  2023-06-30 23:54:07  2023-07-13 18:17:19          NaN
#
# [2256 rows x 43 columns]

# %%
pd.read_csv('../data/bus_stop_list.csv') # to integrate lat lon for bus stop into boundary map
# Out:
#        bus_stop_id  stop_id                                    stop_name  \
# 0                1  1000001                   KL129 FLAT DESA AMAN (OPP)
# 1                2  1000002                 SL254 PERINDUSTRIAN BT CAVES
# 2                3  1000003                            KL1869 TAMAN LAWA
# 3                4  1000004                          KL199 KG SRI DELIMA
# 4                5  1000005                           AJ49 MERDEKA PLACE
# ...            ...      ...                                          ...
# 10394        12473  1008696                          DESA MENTARI BLOK 3
# 10395        12474  1008697                          DESA MENTARI BLOK 7
# 10396        12475  1008698                             MASJID JUMHURIAH
# 10397        12476  1008699              PUSAT KOMERSIAL (MATAHARI MALL)
# 10398        12477  1008700  SMK DATO HARUN/KLINIK KESIHATAN TAMAN MEDAN
#
#           street_name  gpsx_coordinate  gpsy_coordinate use  latitude  \
# 0       JLN DESA AMAN     10144.340780       305.874180   Y  3.097903
# 1           JLN SBC 5     10141.227992       314.016151   Y  3.233603
# 2               JLN D     10139.922980       311.920140   Y  3.198669
# 3           JLN 17/42     10139.996241       311.944784   Y  3.199080
# 4         JLN MERDEKA     10145.862560       308.342760   Y  3.139046
# ...               ...              ...              ...  ..       ...
# 10394    JLN PJS 5/12     10137.170180       304.716240   Y  3.078604
# 10395    JLN PJS 6/5G     10137.152360       304.799580   Y  3.079993
# 10396     JLN PJS 2/7     10138.224500       304.938900   Y  3.082315
# 10397     JLN PJS 2/7     10138.207160       304.810560   Y  3.080176
# 10398     JLN PJS 2/2     10138.094900       304.704540   Y  3.078409
#
#         longitude  enter_angle  stop_variant
# 0      101.739013        349.0           NaN
# 1      101.687133        270.0           NaN
# 2      101.665383        290.0           NaN
# 3      101.666604        198.0           NaN
# 4      101.764376        203.0           NaN
# ...           ...          ...           ...
# 10394  101.619503        256.0           NaN
# 10395  101.619206         27.0           NaN
# 10396  101.637075        193.0           NaN
# 10397  101.636786        188.0           NaN
# 10398  101.634915        282.0           NaN
#
# [10399 rows x 11 columns]

# %%
pd.read_csv('../data/depot.csv') # to create state name columns , parliamentary boundary columns ,
# Out:
#     depot_id            depot_name  state_id  depot_status  category zone  \
# 0          1                Sentul         1             0         1  RKL
# 1          2            Batu Caves         1             1         1  RKL
# 2          3              Melawati         1             0         1  RKL
# 3          4                Maluri         1             1         1  RKL
# 4          5        Cheras Selatan         1             1         1  RKL
# 5          6                   OKR         1             0         1  RKL
# 6          7             Shah Alam         1             1         1  RKL
# 7          8             Asia Jaya         1             0         1  RKL
# 8          9                Kepong         1             0         1  RKL
# 9         10               Kuantan         8             1         1  RKN
# 10        11        Tanjung Bungah         5             1         1  RPG
# 11        12         Sungai Nibong         5             1         1  RPG
# 12        13             Weld Quay         5             1         1  RPG
# 13        14           Balik Pulau         5             1         1  RPG
# 14        15            Mak Mandin         5             1         1  RPG
# 15        16          Nibong Tebal         5             1         1  RPG
# 16        17          Lorong Kulit         5             1         1  RPG
# 17        18            BRT Sunway         1             1         2  BRT
# 18        19             Kamunting         5             0         1  RPG
# 19        20               Academy         1             0         0  ACD
# 20        21      MRT Sungai Buloh         1             1         3  MRT
# 21        22            MRT Kajang         1             1         3  MRT
# 22        23               Manjung         5             0         1  RPG
# 23        24         Sungai Petani         5             0         1  RPG
# 24        25  Central Workshop CHS         1             0         0  RKL
# 25        26           MRT Jinjang         1             1         3  MRT
# 26        27           MRT Serdang         1             1         1  RKL
# 27        28             Putrajaya         1             1         1  RKL
#
#     code
# 0    STL
# 1    BCV
# 2    MLW
# 3    MLR
# 4    CHS
# 5    OKR
# 6    SHA
# 7    ASJ
# 8    KPG
# 9    SMB
# 10    TB
# 11    SN
# 12    WQ
# 13    BP
# 14    MM
# 15    NT
# 16    LK
# 17   SWY
# 18    KM
# 19    AC
# 20   SGB
# 21   KJG
# 22    MJ
# 23    SP
# 24  CWCS
# 25   JJG
# 26   SDG
# 27   PTJ

# %%
pd.read_csv('../data/eng_bus_repair.csv')
# Out:
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (15,22,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           br_id     br_date br_timetype  depot_id loc_code br_busno  \
# 0        974044  2022-01-01          AM         2      CWS  PJH4804
# 1        974045  2022-01-01          AM         2      CWS  PJJ1894
# 2        974046  2022-01-01          AM         2      CWS  PJJ4919
# 3        974047  2022-01-01          AM         2      CWS  WUW1356
# 4        974048  2022-01-01          AM         2      CWS  WVA4383
# ...         ...         ...         ...       ...      ...      ...
# 327357  1352630  2023-04-26          PM        27      KJG  VAE7340
# 327358  1352631  2023-04-26          PM        27      SDG  PJJ5202
# 327359  1352632  2023-04-26          PM        27      KJG  WVD1492
# 327360  1352633  2023-04-26          PM        27      KJG  WUY4969
# 327361  1352634  2023-04-26          PM        27      KJG  CDH7532
#
#        br_bus_status br_date_entry br_repair_status  \
# 0                RTW    2021-12-05            MAJOR
# 1                RTW    2021-05-25            MAJOR
# 2                RTW    2021-12-08            MAJOR
# 3                RTW    2021-11-02            MAJOR
# 4                RTW    2021-11-19            MAJOR
# ...              ...           ...              ...
# 327357           RTW    2023-04-17       INC.REPAIR
# 327358           RTW    2023-02-01         PUSPAKOM
# 327359           RTW    2023-04-26         PUSPAKOM
# 327360           RTW    2023-04-26         PUSPAKOM
# 327361           RTW    2023-04-26         PUSPAKOM
#
#                                         br_entry_status  \
# 0                                     BD- ENGINE FAULTY
# 1       BDW-SKRU COMPRESSOR TANGGAL /ENGINE BUNYI KASAR
# 2                           GEAR BOX PROBLEM- GEAR SLIP
# 3                            ENGINE FAULTY- TIMING GEAR
# 4                                  ENGINE SYSTEM FAULTY
# ...                                                 ...
# 327357                    SIDE PANEL BODY KIRI TERKOPAK
# 327358                                     OPEN DATE B2
# 327359                              PUSPAKOM INSPECTION
# 327360                              PUSPAKOM INSPECTION
# 327361                              PUSPAKOM INSPECTION
#
#                              br_current_status br_waiting_part  \
# 0                       SEND CWS ON 29.12.2021              No
# 1                      SEND TO CW AT 23/8/2021              No
# 2                  Send CWS on date 30.12.2021              No
# 3       SEND CWS 09.11.2021 TO PROGRESS REPAIR              No
# 4                  SEND CWS ON DATE 23.11.2021              No
# ...                                        ...             ...
# 327357                             IN PROGRESS              No
# 327358                             IN PROGRESS              No
# 327359                             IN PROGRESS              No
# 327360                             IN PROGRESS              No
# 327361                             IN PROGRESS              No
#
#        br_waiting_services br_warranty   br_nt_no  br_mo_no  \
# 0                       No          No  200492504  11198733
# 1                       No          No  200466638  11147714
# 2                       No          No  200493032  11199657
# 3                       No          No   11189367  11860613
# 4                       No          No  200490200  11194239
# ...                    ...         ...        ...       ...
# 327357                  No          No        NaN       NaN
# 327358                  No          No        NaN       NaN
# 327359                  No          No        NaN       NaN
# 327360                  No          No        NaN       NaN
# 327361                  No          No        NaN       NaN
#
#        br_target_completed br_date_roadtax br_date_puspakom  \
# 0               2022-01-31      2022-04-05       2022-04-05
# 1               2022-01-31      2021-08-15       2021-08-15
# 2               2022-01-28      2022-05-11       2022-05-11
# 3               2022-01-31      2021-11-20       2021-11-20
# 4               2022-01-31      2022-05-03       2022-05-03
# ...                    ...             ...              ...
# 327357          2023-05-17      2024-01-10       2024-01-10
# 327358          2023-05-18      2023-11-18       2023-11-18
# 327359          2023-04-26      2023-10-30       2023-10-30
# 327360          2023-04-26      2023-11-03       2023-11-03
# 327361          2023-04-26      2023-10-26       2023-10-26
#
#                           br_remark           dt_created          dt_modified  \
# 0                               NaN  2022-01-01 00:00:50  2022-01-01 07:25:52
# 1                               NaN  2022-01-01 00:00:50  2022-01-01 07:25:52
# 2                               NaN  2022-01-01 00:00:50  2022-01-01 07:25:52
# 3       COPERATE LIVERY (FROM GOKL)  2022-01-01 00:00:50  2022-01-01 07:25:52
# 4                               NaN  2022-01-01 00:00:50  2022-01-01 07:25:52
# ...                             ...                  ...                  ...
# 327357                          NaN  2023-08-10 15:53:13                  NaN
# 327358                          NaN  2023-08-10 15:53:13                  NaN
# 327359                          NaN  2023-08-10 15:53:13                  NaN
# 327360                          NaN  2023-08-10 15:53:13                  NaN
# 327361                          NaN  2023-08-10 15:53:13                  NaN
#
#        br_mh_remark dt_mh_modified
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 327357          NaN            NaN
# 327358          NaN            NaN
# 327359          NaN            NaN
# 327360          NaN            NaN
# 327361          NaN            NaN
#
# [327362 rows x 24 columns]

# %%
pd.read_csv('../data/route_busstop.csv') #to aggregate route id distance
# Out:
#        route_busstop_id  depot  route_id route_no  line_id  bus_stop_id  \
# 0                  1384      5       484      452  U452002       1606.0
# 1                  1385      5       484      452  U452002        108.0
# 2                  1386      5       484      452  U452002       3847.0
# 3                  1387      5       484      452  U452002       1714.0
# 4                  1388      5       484      452  U452002       3308.0
# ...                 ...    ...       ...      ...      ...          ...
# 14323             70884     28      1078     P108  P108002      11685.0
# 14324             70885     28      1078     P108  P108002      11686.0
# 14325             70886     28      1078     P108  P108002      11733.0
# 14326             70887     28      1078     P108  P108002      11734.0
# 14327             70888     28      1078     P108  P108002      11667.0
#
#        stop_id  order  stop_category border hub_stop  ride_zone  alight_zone  \
# 0      1001609      1            NaN      N        N          1            1
# 1      1000108      2            NaN      N        N          1            1
# 2      1003854      3            NaN      N        N          1            1
# 3      1001717      4            NaN      N        N          1            1
# 4      1003313      5            NaN      N        N          1            1
# ...        ...    ...            ...    ...      ...        ...          ...
# 14323  1005602     29            NaN      N        N          1            1
# 14324  1005603     30            NaN      N        N          1            1
# 14325  1005650     31            NaN      N        N          1            1
# 14326  1005651     32            NaN      N        N          1            1
# 14327  1005584     33            NaN      N        N          1            1
#
#        entering_angle distance  popular  municipal  dr           dt_created
# 0               270.0        0      NaN        NaN   1  2020-03-09 11:10:44
# 1               269.0      500      NaN        NaN   1  2020-03-09 11:10:44
# 2               349.0     2000      NaN        NaN   1  2020-03-09 11:10:44
# 3               338.0     2400      NaN        NaN   1  2020-03-09 11:10:44
# 4               342.0     2700      NaN        NaN   1  2020-03-09 11:10:44
# ...               ...      ...      ...        ...  ..                  ...
# 14323             NaN    16626      NaN        NaN   2  2023-08-22 11:06:15
# 14324             NaN    16989      NaN        NaN   2  2023-08-22 11:06:15
# 14325             NaN    17647      NaN        NaN   2  2023-08-22 11:06:15
# 14326             NaN    17982      NaN        NaN   2  2023-08-22 11:06:15
# 14327             NaN    19500      NaN        NaN   2  2023-08-22 11:06:15
#
# [14328 rows x 19 columns]

# %%
pd.read_csv('../data/route.csv') #to aggregate route id distance
# Out:
#      route_id route_no route_no_cbts            route_origin  \
# 0           1     B103        XB1030                     NaN
# 1           2     B112        XB1120                     NaN
# 2           3     B114        XB1140                     NaN
# 3           4     B115        XB1150                     NaN
# 4           5       U1        XU0010                     NaN
# ..        ...      ...           ...                     ...
# 977      1165     MS02         H4200  MRT PUTRAJAYA SENTRAL
# 978      1166     MS02         H4200  MRT PUTRAJAYA SENTRAL
# 979      1167     MS03         H4300  MRT PUTRAJAYA SENTRAL
# 980      1168     MS03         H4300  MRT PUTRAJAYA SENTRAL
# 981      1169     MS03         H4300  MRT PUTRAJAYA SENTRAL
#
#           route_destination route_type route_category route_service  \
# 0                       NaN          0         Normal         RAPID
# 1                       NaN          0         Normal         RAPID
# 2                       NaN          0         Normal         RAPID
# 3                       NaN          0         Normal         RAPID
# 4                       NaN      UTAMA         Normal         RAPID
# ..                      ...        ...            ...           ...
# 977  KOMPLEKS NASYRUL QURAN      OTHER            NaN         RAPID
# 978  KOMPLEKS NASYRUL QURAN      OTHER            NaN         RAPID
# 979        MARINA PUTRAJAYA      OTHER            NaN         RAPID
# 980        MARINA PUTRAJAYA      OTHER            NaN         RAPID
# 981        MARINA PUTRAJAYA      OTHER            NaN         RAPID
#
#      route_corridor route_name  \
# 0               NaN     NONAME
# 1               NaN     NONAME
# 2               NaN     NONAME
# 3               NaN     NONAME
# 4               NaN     NONAME
# ..              ...        ...
# 977             NaN        NaN
# 978             NaN        NaN
# 979             NaN        NaN
# 980             NaN        NaN
# 981             NaN        NaN
#
#                                          route_desc  route_dist_in  \
# 0              TITIWANGSA - BKT BINTANG via KG BARU            NaN
# 1                               KL SENTRAL - MALURI            NaN
# 2                      MALURI - TITIWANGSA via KLCC            NaN
# 3                        JLN SULTAN MOHD - PARLIMEN            NaN
# 4                     PINGGIRAN BT CAVES - CHOW KIT            NaN
# ..                                              ...            ...
# 977  MRT Putrajaya Sentral ~ Kompleks Nasyrul Quran            NaN
# 978  MRT Putrajaya Sentral ~ Kompleks Nasyrul Quran            NaN
# 979        MRT Putrajaya Sentral ~ Marina Putrajaya            NaN
# 980        MRT Putrajaya Sentral ~ Marina Putrajaya            NaN
# 981        MRT Putrajaya Sentral ~ Marina Putrajaya            NaN
#
#      route_dist_out  state_id  depot_id  status  freq_min  freq_max  total_km  \
# 0               NaN         1         1       5       0.0       0.0      15.2
# 1               NaN         1         1       5       0.0       0.0      19.3
# 2               NaN         1         1       5       0.0       0.0      22.8
# 3               NaN         1         1       5       0.0       0.0      18.5
# 4               NaN         1         1       5       0.0       0.0      33.6
# ..              ...       ...       ...     ...       ...       ...       ...
# 977         24800.0         1         4       1       NaN       NaN       NaN
# 978         24800.0         1        22       1       NaN       NaN       NaN
# 979         23700.0         1         5       1       NaN       NaN       NaN
# 980         23700.0         1         4       1       NaN       NaN       NaN
# 981         23700.0         1        22       1       NaN       NaN       NaN
#
#      km_per_trip  travel_time deadmileage line_id  zone pis_profile
# 0            NaN          0.0         NaN     NaN     0         NaN
# 1            NaN          0.0         NaN     NaN     0         NaN
# 2            NaN          0.0         NaN     NaN     0         NaN
# 3            NaN          0.0         NaN     NaN     0         NaN
# 4            NaN          0.0         NaN     NaN     0         NaN
# ..           ...          ...         ...     ...   ...         ...
# 977          NaN          NaN        64.5     NaN     0         NaN
# 978          NaN          NaN        64.5     NaN     0         NaN
# 979          NaN          NaN        64.5     NaN     0         NaN
# 980          NaN          NaN        64.5     NaN     0         NaN
# 981          NaN          NaN        64.5     NaN     0         NaN
#
# [982 rows x 25 columns]

# %%
#rtd=
pd.read_csv('../data/rtd.csv') #to hi lite descriptive stat for repair cause , need an etl to standardize
#rtd.iloc[0,0]
# Out:
#        rtd_id    rtd_date         rtd_time  depot_id  route_id   bus_no  \
# 0      209514  2022-01-01  0 days 05:50:00         5       671  WQR7493
# 1      209515  2022-01-01  0 days 06:53:00        15       278   PJH224
# 2      209516  2022-01-01  0 days 07:02:00        22       775   VH4089
# 3      209517  2022-01-01  0 days 07:03:00         2       851  PJK2722
# 4      209518  2022-01-01  0 days 07:02:00        22       869   VK6258
# ...       ...         ...              ...       ...       ...      ...
# 41824  251377  2023-06-30  0 days 22:02:00         4       865   W4087R
# 41825  251378  2023-06-30  0 days 00:00:00         7       729  WVD4738
# 41826  251379  2023-06-30  0 days 22:15:00         4       477   W4860W
# 41827  251380  2023-06-30  0 days 23:00:00         5       679  WPV4598
# 41828  251436  2023-06-01  0 days 13:36:00        22       869   VH4108
#
#        bus_model_id driver_id  reason_rtd  cases  ...  tech_remark  \
# 0                31  TNZITDWB         NaN    1.0  ...          NaN
# 1                26  ATPBIKBV         NaN    5.0  ...          NaN
# 2                25  TQFDAFVP         NaN    1.0  ...          NaN
# 3                26  JTRDUIHR         NaN    1.0  ...          NaN
# 4                25  YTTUSFTH         NaN    1.0  ...          NaN
# ...             ...       ...         ...    ...  ...          ...
# 41824            24  GMBMUENV         NaN    1.0  ...          NaN
# 41825             9  TJTCDBWB         NaN    2.0  ...          NaN
# 41826            24  BVHKWEDQ         NaN    1.0  ...          NaN
# 41827            31  VJVCJPMM         NaN    1.0  ...          NaN
# 41828            25  ACLVPFXS         NaN    1.0  ...          NaN
#
#           time_arrived                                          fc_remark  \
# 0      0 days 06:00:00  Bus Repair and Captain Continue Duty With New Bus
# 1      0 days 07:15:00  Bus Repair and Captain Continue Duty With New Bus
# 2      0 days 07:30:00  Bus Repair and Captain Continue Duty With New Bus
# 3      0 days 08:20:00  Bus Repair and Captain Continue Duty With New Bus
# 4      0 days 07:50:00  Bus Repair and Captain Continue Duty With New Bus
# ...                ...                                                ...
# 41824  0 days 23:00:00                    Bus Repair and Captain End Duty
# 41825              NaN                                                NaN
# 41826  0 days 23:00:00                    Bus Repair and Captain End Duty
# 41827              NaN                                                NaN
# 41828  0 days 14:30:00  Bus Repair and Captain Continue Duty With New Bus
#
#          rtd_sap_id ope_approvedby  ope_remark  status             rtd_sn  \
# 0      2.004964e+08            NaN         NaN       1  RTD05220101B7L001
# 1               NaN            NaN         NaN       1  RTD15220101S70002
# 2      2.004964e+08            NaN         NaN       1  RTD22220101S5M003
# 3      2.004964e+08            NaN         NaN       1  RTD02220101S70004
# 4      2.004964e+08            NaN         NaN       1  RTD22220101S5M005
# ...             ...            ...         ...     ...                ...
# 41824  2.306305e+09            NaN         NaN       1  RTD04230630S5B073
# 41825           NaN            NaN         NaN       1  RTD07230630SK7074
# 41826  2.306305e+09            NaN         NaN       1  RTD04230630S5B075
# 41827           NaN            NaN         NaN       1  RTD05230630B7L076
# 41828  2.005845e+08            NaN         NaN       1  RTD22230701S5M056
#
#                         telegram_desc           dt_created
# 0                Lambang stop menyala  2022-01-01 05:51:13
# 1                 LED TIDAK BERFUNGSI  2022-01-01 06:59:06
# 2                  AIR SYSTEM PROBLEM  2022-01-01 07:03:32
# 3                       Aircond panas  2022-01-01 07:03:34
# 4                        DOOR PROBLEM  2022-01-01 07:04:49
# ...                               ...                  ...
# 41824           Airbellow depan bocor  2023-06-30 22:11:39
# 41825                  BC sakit perut  2023-06-30 22:14:48
# 41826                 ABS Malfunction  2023-06-30 22:16:18
# 41827  compressor aircond malfunction  2023-06-30 23:01:25
# 41828    FRONT PASSENGER DOOR PROBLEM  2023-07-01 15:06:51
#
# [41829 rows x 27 columns]

# %%
import pandas as pd
import numpy as np

temp=pd.DataFrame()
print(temp.iloc[0,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13988\1668994390.py in <module>
#       3
#       4 temp=pd.DataFrame()
# ----> 5 print(temp.iloc[0,0])
#
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     752         for i, k in enumerate(key):
#     753             try:
# --> 754                 self._validate_key(k, i)
#     755             except ValueError as err:
#     756                 raise ValueError(
#
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1407             return
#    1408         elif is_integer(key):
# -> 1409             self._validate_integer(key, axis)
#    1410         elif isinstance(key, tuple):
#    1411             # a tuple should already have been caught by this point
#
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds
