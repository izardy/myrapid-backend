# %%
import pandas as pd
import numpy as np

# %%
infoTRIP=pd.read_csv('../data/trip_departure/processed/td_agg.csv')
infoTRIP
# Out:
#          ope_date  depot_id line_id   bus_no              point_a  \
# 0      2022-10-01        10   K1000  CDH7753             H/BANDAR
# 1      2022-10-01        10   K1000  CDD1442             H/BANDAR
# 2      2022-10-01        10   K1000  CDH2338             H/BANDAR
# 3      2022-10-01        10   K1000  CDH5966             H/BANDAR
# 4      2022-10-01        10   K1000  CDH7750             H/BANDAR
# ...           ...       ...     ...      ...                  ...
# 11542  2022-10-21         5   U5900   WB759L  BANDAR SUNGAI LONG
# 11543  2022-10-21         5   U4000  WA1376G       DAMAI PERDANA
# 11544  2022-10-21         5   U6500  WPV6981  KL Santral (Petron)
# 11545  2022-10-21         2   U1910  WUX5671       SRI SEGAMBIUT
# 11546  2022-10-21         2   U1910  WUW8426       SRI SEGAMBIUT
#
#                     point_b  ttl_td_id  ttl_captain_id  ttl_point_a  \
# 0            GAMBANG RESORT         14               1            1
# 1            GAMBANG RESORT         12               1            1
# 2            GAMBANG RESORT         12               1            1
# 3            GAMBANG RESORT         12               1            1
# 4            GAMBANG RESORT          8               1            1
# ...                     ...        ...             ...          ...
# 11542            LEBUH PUDU         16               1            1
# 11543  HUB LEBUH PUDU via B         10               1            1
# 11544            Pasar Seni         32               1            1
# 11545             CHOW KIT          43               2            1
# 11546             CHOW KIT          48               2            1
#
#        ttl_point_b  ...  avg_diff_minutes_idle_mode  \
# 0                1  ...                   61.783333
# 1                1  ...                   32.366667
# 2                1  ...                   57.560000
# 3                1  ...                   53.123333
# 4                1  ...                   24.000000
# ...            ...  ...                         ...
# 11542            1  ...                   29.302381
# 11543            1  ...                   18.900000
# 11544            1  ...                   13.816667
# 11545            1  ...                   14.519048
# 11546            1  ...                   13.479710
#
#        avg_diff_minutes_to_point_a  med_diff_minutes_from_point_a  \
# 0                        68.311111                      72.258333
# 1                        88.500000                      73.366667
# 2                        60.505556                      83.266667
# 3                        70.572222                      76.666667
# 4                        86.300000                      94.383333
# ...                            ...                            ...
# 11542                    82.491667                      72.250000
# 11543                    89.827778                      63.291667
# 11544                    70.683333                       5.500000
# 11545                    33.007576                      29.250000
# 11546                    32.330556                      30.750000
#
#        med_diff_minutes_idle_mode  med_diff_minutes_to_point_a  max_speed  \
# 0                       57.675000                    80.316667       28.0
# 1                       41.483333                    82.150000       56.0
# 2                       51.216667                    62.033333       59.0
# 3                       44.350000                    71.983333       45.0
# 4                       18.483333                    86.300000       56.0
# ...                           ...                          ...        ...
# 11542                    8.500000                    74.741667       46.0
# 11543                    7.391667                    75.350000       35.0
# 11544                    3.500000                    69.241667       24.0
# 11545                    7.500000                    33.000000       38.0
# 11546                    8.500000                    31.250000       41.0
#
#        min_speed  avg_speed  med_speed  ttl_td_completed
# 0            8.0  16.181818       15.0              14.0
# 1           15.0  24.090909       19.0              12.0
# 2            8.0  21.777778       17.0              12.0
# 3            8.0  17.083333       14.0              12.0
# 4            6.0  21.285714       16.0               8.0
# ...          ...        ...        ...               ...
# 11542        1.0  25.142857       29.0              16.0
# 11543        4.0  14.700000       13.0              10.0
# 11544        1.0  11.611111       11.5              32.0
# 11545        1.0  15.846154       13.0              43.0
# 11546        1.0  15.617647       15.5              48.0
#
# [11547 rows x 27 columns]

# %%
infoBAS=pd.read_csv('../data/processed/InfoBAS.csv')
infoBAS
# Out:
# c:\Users\izard\anaconda3\envs\pytorch\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           ope_date  depot_id line_id   bus_no      br_id br_repair_status  \
# 0       2022-10-01        10   K1000  CDH7753        NaN              NaN
# 1       2022-10-01        10   K1000  CDD1442        NaN              NaN
# 2       2022-10-01        10   K1000  CDH2338        NaN              NaN
# 3       2022-10-01        10   K1000  CDH5966  1129191.0            MAJOR
# 4       2022-10-01        10   K1000  CDH7750  1129194.0           SCH.PM
# ...            ...       ...     ...      ...        ...              ...
# 358143  2022-09-30         7   T7910  WVA2966        NaN              NaN
# 358144  2022-09-30         7   T8500  WUT8479        NaN              NaN
# 358145  2022-09-30         7   T8500  WVD3251        NaN              NaN
# 358146  2022-09-30         7   T8500  WVE5806        NaN              NaN
# 358147  2022-09-30         7   T7820  WVD2353        NaN              NaN
#
#                    br_entry_status     br_date br_date_entry  \
# 0                              NaN         NaN           NaN
# 1                              NaN         NaN           NaN
# 2                              NaN         NaN           NaN
# 3       BAS MENYENTAP MASA MEMANDU  2022-10-01    2022-10-01
# 4                         SERVIS A  2022-10-01    2022-10-01
# ...                            ...         ...           ...
# 358143                         NaN         NaN           NaN
# 358144                         NaN         NaN           NaN
# 358145                         NaN         NaN           NaN
# 358146                         NaN         NaN           NaN
# 358147                         NaN         NaN           NaN
#
#        br_target_completed  ...  fc_remark          label_3  date_issues  \
# 0                      NaN  ...        NaN              NaN          NaN
# 1                      NaN  ...        NaN              NaN          NaN
# 2                      NaN  ...        NaN              NaN          NaN
# 3               2022-10-02  ...        NaN              NaN   2022-10-01
# 4               2022-10-02  ...        NaN              NaN   2022-10-01
# ...                    ...  ...        ...              ...          ...
# 358143                 NaN  ...        NaN              NaN          NaN
# 358144                 NaN  ...        NaN              NaN          NaN
# 358145                 NaN  ...        NaN  return to depot   2022-09-30
# 358146                 NaN  ...        NaN              NaN          NaN
# 358147                 NaN  ...        NaN              NaN          NaN
#
#        capt_id  bcc_acc_id  acc_date bus_damage  eng_find label_1  \
# 0          NaN         NaN       NaN        NaN       NaN     NaN
# 1          NaN         NaN       NaN        NaN       NaN     NaN
# 2          NaN         NaN       NaN        NaN       NaN     NaN
# 3          NaN         NaN       NaN        NaN       NaN     NaN
# 4          NaN         NaN       NaN        NaN       NaN     NaN
# ...        ...         ...       ...        ...       ...     ...
# 358143     NaN         NaN       NaN        NaN       NaN     NaN
# 358144     NaN         NaN       NaN        NaN       NaN     NaN
# 358145     NaN         NaN       NaN        NaN       NaN     NaN
# 358146     NaN         NaN       NaN        NaN       NaN     NaN
# 358147     NaN         NaN       NaN        NaN       NaN     NaN
#
#                   label
# 0           normal trip
# 1           normal trip
# 2           normal trip
# 3         engine repair
# 4         engine repair
# ...                 ...
# 358143      normal trip
# 358144      normal trip
# 358145  return to depot
# 358146      normal trip
# 358147      normal trip
#
# [358148 rows x 29 columns]

# %%
pd.merge(infoTRIP,infoBAS.drop(columns=['label_1','label_2','label_3']),how='left',on=['ope_date','depot_id','bus_no']).to_csv('../data/model/data_model.csv',index=False)
